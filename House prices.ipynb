# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dftrain = pd.read_csv('train.csv')
dftest = pd.read_csv('test.csv')

# %%
dftrain.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
dftest.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# 1         Lvl    AllPub      ...                 0        0    NaN    NaN
# 2         Lvl    AllPub      ...                 0        0    NaN  MnPrv
# 3         Lvl    AllPub      ...                 0        0    NaN    NaN
# 4         HLS    AllPub      ...               144        0    NaN    NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
plt.figure(figsize=(20,20))
plt.subplot(2,1,1)
sns.heatmap(dftrain.drop(['Id','SalePrice'],axis=1).isnull(),yticklabels=False,cbar=False,cmap='viridis')
plt.subplot(2,1,2)
sns.heatmap(dftest.drop('Id',axis=1).isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
#['Id','Alley','PoolQC','Fence','MiscFeature','FireplaceQu']
temp = pd.concat([dftrain,dftest],)
temp
# temp.drop(['Id','Alley','PoolQC','Fence','MiscFeature','FireplaceQu'],axis=1,inplace=True)
# ind=temp[temp['LotFrontage'].isnull()].index
# temp.loc[ind,'LotFrontage']=temp['LotFrontage'].mean()
# temp
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType BsmtCond  \
# 0          856       854          0   NaN             3     1Fam       TA
# 1         1262         0          0   NaN             3     1Fam       TA
# 2          920       866          0   NaN             3     1Fam       TA
# 3          961       756          0   NaN             3     1Fam       Gd
# 4         1145      1053          0   NaN             4     1Fam       TA
# 5          796       566        320   NaN             1     1Fam       TA
# 6         1694         0          0   NaN             3     1Fam       TA
# 7         1107       983          0   NaN             3     1Fam       TA
# 8         1022       752          0   NaN             2     1Fam       TA
# 9         1077         0          0   NaN             2   2fmCon       TA
# 10        1040         0          0   NaN             3     1Fam       TA
# 11        1182      1142          0   NaN             4     1Fam       TA
# ...

# %%
dftrain.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
# dftrain.info()

# %%
plt.figure(figsize=(20,8))
sns.heatmap(dftrain.drop('Id',axis=1).isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
dftrain2 = dftrain.drop(['Id','Alley','PoolQC','Fence','MiscFeature','FireplaceQu'],axis=1)

# %%
plt.figure(figsize=(20,8))
sns.heatmap(dftrain2.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# # I'll use the mean to fill in the LotFrontage

# %%
ind=dftrain2[dftrain2['LotFrontage'].isnull()].index
dftrain3 = dftrain2.copy()
dftrain3.loc[ind,'LotFrontage']=dftrain2['LotFrontage'].mean()

# %%
dftrain3.head(15)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0           60       RL    65.000000     8450   Pave      Reg         Lvl
# 1           20       RL    80.000000     9600   Pave      Reg         Lvl
# 2           60       RL    68.000000    11250   Pave      IR1         Lvl
# 3           70       RL    60.000000     9550   Pave      IR1         Lvl
# 4           60       RL    84.000000    14260   Pave      IR1         Lvl
# 5           50       RL    85.000000    14115   Pave      IR1         Lvl
# 6           20       RL    75.000000    10084   Pave      Reg         Lvl
# 7           60       RL    70.049958    10382   Pave      IR1         Lvl
# 8           50       RM    51.000000     6120   Pave      Reg         Lvl
# 9          190       RL    50.000000     7420   Pave      Reg         Lvl
# 10          20       RL    70.000000    11200   Pave      Reg         Lvl
# 11          60       RL    85.000000    11924   Pave      IR1         Lvl
# ...

# %%
plt.figure(figsize=(20,8))
sns.heatmap(dftrain3.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
dftrain3.dropna(inplace=True)

# %%
dftrain3.select_dtypes(exclude=['floating','integer']).T.apply(lambda x: x.nunique(), axis=1)
# Out:
# MSZoning          5
# Street            2
# LotShape          4
# LandContour       4
# Utilities         2
# LotConfig         5
# LandSlope         3
# Neighborhood     25
# Condition1        9
# Condition2        8
# BldgType          5
# HouseStyle        8
# RoofStyle         6
# RoofMatl          8
# Exterior1st      14
# Exterior2nd      16
# MasVnrType        4
# ExterQual         4
# ExterCond         4
# Foundation        5
# BsmtQual          4
# BsmtCond          4
# BsmtExposure      4
# BsmtFinType1      6
# BsmtFinType2      6
# Heating           4
# HeatingQC         5
# CentralAir        2
# Electrical        5
# KitchenQual       4
# Functional        7
# GarageType        6
# GarageFinish      3
# GarageQual        5
# GarageCond        5
# PavedDrive        3
# SaleType          9
# SaleCondition     6
# dtype: int64

# %%
categories=pd.get_dummies(dftrain3.select_dtypes(exclude=['floating','integer']))
Y_train = pd.DataFrame(dftrain3['SalePrice'])
dftrain4 = dftrain3.select_dtypes(include=['floating','integer']).drop('SalePrice',axis=1)
dftrain4 = pd.concat([dftrain4,categories],axis=1)
X_train = dftrain4.copy()
X_train.head(10)
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60    65.000000     8450            7            5       2003
# 1          20    80.000000     9600            6            8       1976
# 2          60    68.000000    11250            7            5       2001
# 3          70    60.000000     9550            7            5       1915
# 4          60    84.000000    14260            8            5       2000
# 5          50    85.000000    14115            5            5       1993
# 6          20    75.000000    10084            8            5       2004
# 7          60    70.049958    10382            7            6       1973
# 8          50    51.000000     6120            7            5       1931
# 9         190    50.000000     7420            5            6       1939
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2          ...            \
# 0          2003       196.0         706           0          ...
# ...

# %%
def dataConverter(df):
    # droping columns with highly missing data
    dftrain2 = df.drop(['Id','Alley','PoolQC','Fence','MiscFeature','FireplaceQu'],axis=1)
    
    # filling missing data with average
    ind=dftrain2[dftrain2['LotFrontage'].isnull()].index
    dftrain3 = dftrain2.copy()
    dftrain3.loc[ind,'LotFrontage']=dftrain2['LotFrontage'].mean()
    
    # droping missing data in catagorical features
    dftrain3.dropna(inplace=True)
    
    # performing one_hot catogrization
    categories=pd.get_dummies(dftrain3.select_dtypes(exclude=['floating','integer']))
    if 'SalePrice' in df.columns: 
        dftrain4 = dftrain3.select_dtypes(include=['floating','integer']).drop('SalePrice',axis=1)
    else:
        dftrain4 = dftrain3.select_dtypes(include=['floating','integer'])
    
    dftrain4 = pd.concat([dftrain4,categories],axis=1)
    
    # getting the labels dataframe
    if 'SalePrice' in df.columns: 
        Y = pd.DataFrame(dftrain3['SalePrice'])
    else:
        Y = None
    
    # copying the features dataframe with one_hot catogrization into the variable X_train
    X = dftrain4.copy()
    
    return (X,Y)

# %%
(x_train,Y_train)=dataConverter(dftrain)

# %% [markdown]
# # Let's train a logitic regression model

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
Y_train.size
# Out:
# 1338

# %%
Y_train.as_matrix().reshape(Y_train.size,)
# Out:
# array([208500, 181500, 223500, ..., 266500, 142125, 147500])

# %%
(x_train,Y_train)=dataConverter(dftrain)
model.fit(x_train.as_matrix(),Y_train.as_matrix().reshape(Y_train.size,))
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
(x_test,_)=dataConverter(dftest)
x_test.columns
for i in range(len(x_train.columns)):
    if i >= len(x_test.columns):
        ii = len(x_test.columns)-1
    else:
        ii = i
    print(str(i)+': Test: {}\t\tTrain: {}'.format(dftest.columns[ii],dftrain.columns[i])+"\t\t {}".format(dftest.columns[ii]==dftrain.columns[i]))
# Out:
# 0: Test: Id		Train: Id		 True
# 1: Test: MSSubClass		Train: MSSubClass		 True
# 2: Test: MSZoning		Train: MSZoning		 True
# 3: Test: LotFrontage		Train: LotFrontage		 True
# 4: Test: LotArea		Train: LotArea		 True
# 5: Test: Street		Train: Street		 True
# 6: Test: Alley		Train: Alley		 True
# 7: Test: LotShape		Train: LotShape		 True
# 8: Test: LandContour		Train: LandContour		 True
# 9: Test: Utilities		Train: Utilities		 True
# 10: Test: LotConfig		Train: LotConfig		 True
# 11: Test: LandSlope		Train: LandSlope		 True
# 12: Test: Neighborhood		Train: Neighborhood		 True
# 13: Test: Condition1		Train: Condition1		 True
# 14: Test: Condition2		Train: Condition2		 True
# 15: Test: BldgType		Train: BldgType		 True
# 16: Test: HouseStyle		Train: HouseStyle		 True
# 17: Test: OverallQual		Train: OverallQual		 True
# 18: Test: OverallCond		Train: OverallCond		 True
# 19: Test: YearBuilt		Train: YearBuilt		 True
# 20: Test: YearRemodAdd		Train: YearRemodAdd		 True
# ...

# %%
len(x_test.columns)
# Out:
# 245

# %%
pred=model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-174-601c035b18eb> in <module>()
# ----> 1 pred=model.predict(x_test)
#
# /Users/aabuaish/anaconda/lib/python3.5/site-packages/sklearn/linear_model/base.py in predict(self, X)
#     334             Predicted class label per sample.
#     335         """
# --> 336         scores = self.decision_function(X)
#     337         if len(scores.shape) == 1:
#     338             indices = (scores > 0).astype(np.int)
#
# /Users/aabuaish/anaconda/lib/python3.5/site-packages/sklearn/linear_model/base.py in decision_function(self, X)
#     315         if X.shape[1] != n_features:
#     316             raise ValueError("X has %d features per sample; expecting %d"
# --> 317                              % (X.shape[1], n_features))
#     318
#     319         scores = safe_sparse_dot(X, self.coef_.T,
#
# ...

# %%
for x in dftrain3.select_dtypes(exclude=['floating','integer']):
    print(dftrain3[x].unique())
# Out:
# ['RL' 'RM' 'C (all)' 'FV' 'RH']
# ['Pave' 'Grvl']
# ['Reg' 'IR1' 'IR2' 'IR3']
# ['Lvl' 'Bnk' 'Low' 'HLS']
# ['AllPub' 'NoSeWa']
# ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
# ['Gtl' 'Mod' 'Sev']
# ['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'NAmes' 'SawyerW' 'IDOTRR'
#  'MeadowV' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'Edwards' 'NPkVill'
#  'Blmngtn' 'BrDale' 'SWISU' 'Blueste']
# ['Norm' 'Feedr' 'PosN' 'Artery' 'RRAe' 'RRNn' 'RRAn' 'PosA' 'RRNe']
# ['Norm' 'Artery' 'RRNn' 'Feedr' 'PosN' 'PosA' 'RRAn' 'RRAe']
# ['1Fam' '2fmCon' 'TwnhsE' 'Duplex' 'Twnhs']
# ['2Story' '1Story' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin']
# ['Gable' 'Hip' 'Gambrel' 'Mansard' 'Flat' 'Shed']
# ['CompShg' 'WdShngl' 'Metal' 'WdShake' 'Membran' 'Tar&Grv' 'Roll' 'ClyTile']
# ['VinylSd' 'MetalSd' 'Wd Sdng' 'HdBoard' 'BrkFace' 'WdShing' 'CemntBd'
#  'Plywood' 'Stucco' 'AsbShng' 'BrkComm' 'Stone' 'ImStucc' 'CBlock']
# ...

# %%
catagories=pd.get_dummies(dftrain3.select_dtypes(exclude=['floating','integer']))

# %%
xx = pd.DataFrame(data=mat,index=['a','b','c'],columns=['first','second','third'])
xx
# Out:
#    first  second  third
# a      4       6      7
# b      4       7      9
# c      1       9      4

# %%
mat = np.array([[4,6,7],[4,7,9],[1,9,4]])

# %%
xx.loc['a','first']
# Out:
# 4

# %%
xx.loc['a':'b','first']=pd.Series([2,3],index=['a','b'])

# %%
xx
# Out:
#    first  second  third
# a    2.0     6.0    7.0
# b    3.0     7.0    9.0
# c    1.0     9.0    4.0

# %%
pd.Series([2,3],index=['a','b'])
# Out:
# a    2
# b    3
# dtype: int64

# %%
Index(dftrain2['LotFrontage'].isnull()).get_loc(False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-9847e950840c> in <module>()
# ----> 1 Index(dftrain2['LotFrontage'].isnull()).get_loc(False)
#
# NameError: name 'Index' is not defined

# %%
xx.loc[['a','c'],'first']
# Out:
# a    2
# c    1
# Name: first, dtype: int64

# %%
dftrain2['LotFrontage'].mean()
# Out:
# 70.04995836802642
